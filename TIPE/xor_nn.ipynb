# %%
import numpy as np
from encephalon import NN, sigmoid, tanh

# %%
data = np.array([[[1,1]], [[0,1]], [[1,0]], [[0,0]]])
labels = np.array([[0], [1], [1], [0]])

# %%
xor = NN([2,3,1], name="xor", f=tanh, g=sigmoid)

# %%
# xor.load("/home/eleve/xor_2024-07-20T16:30:54.npz")

# %%
# xor.save("xor_tanh_sigmoid")

# %%
xor.train(data, labels, 1000000,learning_rate=0.01)
# Out:
# epoch 100/1000000   error=0.000000
# epoch 200/1000000   error=0.000000
# epoch 300/1000000   error=0.000000
# epoch 400/1000000   error=0.000000
# epoch 500/1000000   error=0.000000
# epoch 600/1000000   error=0.000000
# epoch 700/1000000   error=0.000000
# epoch 800/1000000   error=0.000000
# epoch 900/1000000   error=0.000000
# epoch 1000/1000000   error=0.000000
# epoch 1100/1000000   error=0.000000
# epoch 1200/1000000   error=0.000000
# epoch 1300/1000000   error=0.000000
# epoch 1400/1000000   error=0.000000
# epoch 1500/1000000   error=0.000000
# epoch 1600/1000000   error=0.000000
# epoch 1700/1000000   error=0.000000
# epoch 1800/1000000   error=0.000000
# epoch 1900/1000000   error=0.000000
# epoch 2000/1000000   error=0.000000
# epoch 2100/1000000   error=0.000000
# epoch 2200/1000000   error=0.000000
# epoch 2300/1000000   error=0.000000
# epoch 2400/1000000   error=0.000000
# epoch 2500/1000000   error=0.000000
# epoch 2600/1000000   error=0.000000
# ...

# %%
print(xor.use([[1,1]]))
print(xor.use([[0,1]]))
print(xor.use([[1,0]]))
print(xor.use([[0,0]]))
# Out:
# [[0.00222264]]
# [[0.99998244]]
# [[0.99997291]]
# [[0.00130556]]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


points = []
for x in np.linspace(0, 1, 20):
    for y in np.linspace(0, 1, 20):
        z = xor.use([x,y])
        points.append([x, y, z[0,0]])

points = np.array(points)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c=points[:, 2], cmap="winter")
plt.show()
